# %%
# This is to remove test data from windowed data for training
import os
training_years = ['2020', '2020']
for window_data in os.listdir():
    if 'OBSEA_' not in window_data:
        continue
    
    for fname in os.listdir(window_data + '/OBSEA'):
        if '_label' not in fname:
            continue
        
        year = fname[:4]
        if year not in training_years:
            os.remove(window_data + '/OBSEA/' + fname)
            fname = fname.replace('_label', '')
            os.remove(window_data + '/OBSEA/' + fname)

# %%
# prepare train_val_split
from sklearn.model_selection import train_test_split
import pandas as pd

# read metrics generated by create_window_data
df = pd.read_csv('../metrics.csv', index_col=0)
df = df[(df.index.str.contains('2020')) | (df.index.str.contains('2021'))]# | (df.index.str.contains('2021'))] 
#df.drop(['CBLOF', 'LOF', 'PCC'], axis=1, inplace=True)
# remove rows that have many detectors yielding the same highest score
threshold = 2
max_values = df.max()
is_max = df.eq(max_values)
rows_to_delete = is_max.sum(axis=1) >= threshold
df = df[~rows_to_delete]

# now find the max
df['label'] = df.idxmax(axis=1)
df['label'].value_counts()

# split data for training and valication
validation_size = 0.15
num_samples = len(df)
val_samples = int(num_samples * validation_size)

# Get counts of each class to balance
class_counts = df['label'].value_counts()
min_class_val_size = int(val_samples / len(class_counts))  # Equal number from each class

# Collect indices for the validation set
val_indices = []
for label in class_counts.index:
    indices = df[df['label'] == label].index.tolist()
    val_indices.extend(indices[:min_class_val_size])

# Remaining indices are for training
train_indices = list(set(df.index) - set(val_indices))

# Split the data
train_df = df.loc[train_indices]
val_df = df.loc[val_indices]

# %%
print(f"Training Set Size: {train_df.shape[0]}")
print(f"Validation Set Size: {val_df.shape[0]}")
print("\nTraining Set Distribution:")
print(train_df['label'].value_counts())
print("\nValidation Set Distribution:")
print(val_df['label'].value_counts())
# Out:
# Training Set Size: 461
# Validation Set Size: 78
#
# Training Set Distribution:
# LOF                           159
# Torsk                         122
# Hybrid KNN                     55
# CBLOF                          38
# EncDec-AD                      28
# HBOS                           22
# PCC                            16
# DenoisingAutoEncoder (DAE)      6
# AutoEncoder (AE)                6
# Random Black Forest (RR)        5
# COPOD                           3
# DeepAnT                         1
# Name: label, dtype: int64
#
# Validation Set Distribution:
# LOF                           6
# Torsk                         6
# Hybrid KNN                    6
# CBLOF                         6
# EncDec-AD                     6
# HBOS                          6
# PCC                           6
# AutoEncoder (AE)              6
# DenoisingAutoEncoder (DAE)    6
# Random Black Forest (RR)      6
# COPOD                         6
# DeepAnT                       6
# RobustPCA                     6
# Name: label, dtype: int64

# %%
train_df = train_df.index.tolist() 
val_df = val_df.index.tolist() 
train_df = [x + '.csv' for x in train_df]
val_df = [x + '.csv' for x in val_df]
data2df = {'train_set': train_df,
           'val_set': val_df}
data2df = pd.DataFrame.from_dict(data2df, orient='index')
data2df.to_csv('train_val_split.csv')

# %%
# remember to move train_val_split.csv to reproducibility_guide/

# %%
df
# Out:
#                       AutoEncoder (AE)     CBLOF     COPOD   DeepAnT  \
# OBSEA/2020-11-03.out          0.179869  0.375253  0.274341  0.232109
# OBSEA/2020-03-16.out          0.918716  0.986496  0.917331  0.917366
# OBSEA/2020-06-04.out          0.058839  0.198123  0.082814  0.037289
# OBSEA/2020-12-03.out          0.928263  0.936971  0.919444  0.964719
# OBSEA/2020-10-03.out          0.801085  0.684449  0.462128  0.251890
# ...                                ...       ...       ...       ...
# OBSEA/2020-02-20.out          0.856573  0.980600  0.917560  0.924489
# OBSEA/2020-12-24.out          0.202628  0.245330  0.208912  0.149198
# OBSEA/2020-04-02.out          0.949561  0.976728  0.918826  0.928868
# OBSEA/2021-11-23.out          0.743542  0.981835  0.916887  0.918471
# OBSEA/2020-04-22.out          0.902924  0.983622  0.917102  0.921984
#
#                       DenoisingAutoEncoder (DAE)  EncDec-AD      HBOS  \
# OBSEA/2020-11-03.out                    0.331566   0.204318  0.343748
# OBSEA/2020-03-16.out                    0.886606   0.000000  0.530150
# OBSEA/2020-06-04.out                    0.035201   0.033576  0.124523
# OBSEA/2020-12-03.out                    0.939933   0.972615  0.909556
# OBSEA/2020-10-03.out                    0.793336   0.176748  0.559928
# ...                                          ...        ...       ...
# OBSEA/2020-02-20.out                    0.797864   0.000000  0.530941
# OBSEA/2020-12-24.out                    0.247832   0.224792  0.269665
# OBSEA/2020-04-02.out                    0.915647   0.000000  0.529800
# OBSEA/2021-11-23.out                    0.824987   0.000000  0.558570
# OBSEA/2020-04-22.out                    0.857013   0.000000  0.565791
#
#                       Hybrid KNN       LOF       PCC  RobustPCA  \
# OBSEA/2020-11-03.out    0.154503  0.375253  0.266593   0.246145
# OBSEA/2020-03-16.out    0.744666  0.999000  0.994158   0.636384
# OBSEA/2020-06-04.out    0.033979  0.198123  0.081753   0.031695
# OBSEA/2020-12-03.out    0.974520  0.936971  0.930331   0.998369
# OBSEA/2020-10-03.out    0.595054  0.684449  0.443279   0.095246
# ...                          ...       ...       ...        ...
# OBSEA/2020-02-20.out    0.745352  0.999000  0.994133   0.580729
# OBSEA/2020-12-24.out    0.202537  0.245330  0.219381   0.211030
# OBSEA/2020-04-02.out    0.744787  0.999000  0.997983   0.485937
# OBSEA/2021-11-23.out    0.744395  0.996852  0.984262   0.707630
# OBSEA/2020-04-22.out    0.744696  0.996899  0.996146   0.758127
#
#                       Random Black Forest (RR)     Torsk             label
# OBSEA/2020-11-03.out                  0.497478  0.556411             Torsk
# OBSEA/2020-03-16.out                  0.743174  0.799122               LOF
# OBSEA/2020-06-04.out                  0.038326  0.141590             CBLOF
# OBSEA/2020-12-03.out                  0.945626  0.985211         RobustPCA
# OBSEA/2020-10-03.out                  0.677349  0.283791  AutoEncoder (AE)
# ...                                        ...       ...               ...
# OBSEA/2020-02-20.out                  0.774125  0.843532               LOF
# OBSEA/2020-12-24.out                  0.222021  0.664003             Torsk
# OBSEA/2020-04-02.out                  0.699438  0.815355               LOF
# OBSEA/2021-11-23.out                  0.573194  0.826250               LOF
# OBSEA/2020-04-22.out                  0.816826  0.829291               LOF
#
# [539 rows x 14 columns]

# %%
df = pd.read_csv('../metrics.csv', index_col=0)
df.fillna(0, inplace=True)
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(df, showfliers=False, orient='v')
plt.xticks(rotation=90)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-7f880795f0e2> in ?()
# ----> 4 df = pd.read_csv('../metrics.csv', index_col=0)
#       5 import seaborn as sns
#       6 import matplotlib.pyplot as plt
#       7 sns.boxplot(df, showfliers=False, orient='v')
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in ?(*args, **kwargs)
#      42                         ", ".join(kwonly_args[:extra_args])),
#      43                 FutureWarning
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in ?(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2226     whis=1.5, ax=None,
#    2227     **kwargs
#    2228 ):
#    2229
# -> 2230     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2231                           orient, color, palette, saturation,
#    2232                           width, dodge, fliersize, linewidth)
#    2233
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in ?(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     402     def __init__(self, x, y, hue, data, order, hue_order,
#     403                  orient, color, palette, saturation,
#     404                  width, dodge, fliersize, linewidth):
#     405
# --> 406         self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     407         self.establish_colors(color, palette, saturation)
#     408
#     409         self.dodge = dodge
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in ?(self, x, y, hue, data, orient, order, hue_order, units)
#     152                     err = "Could not interpret input '{}'".format(var)
#     153                     raise ValueError(err)
#     154
#     155             # Figure out the plotting orientation
# --> 156             orient = infer_orient(
#     157                 x, y, orient, require_numeric=self.require_numeric
#     158             )
#     159
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_core.py in ?(x, y, orient, require_numeric)
#    1284     TypeError: When dependant variable is not numeric, with `require_numeric`
#    1285
#    1286     """
#    1287
# -> 1288     x_type = None if x is None else variable_type(x)
#    1289     y_type = None if y is None else variable_type(y)
#    1290
#    1291     nonnumeric_dv_error = "{} orientation requires numeric `{}` variable."
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_core.py in ?(vector, boolean_type)
#    1199         Name identifying the type of data in the vector.
#    1200
#    1201     """
#    1202     # Special-case all-na data, which is always "numeric"
# -> 1203     if pd.isna(vector).all():
#    1204         return "numeric"
#    1205
#    1206     # Special-case binary/boolean data, allow caller to determine
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in ?(self)
#    1525     @final
#    1526     def __nonzero__(self) -> NoReturn:
# -> 1527         raise ValueError(
#    1528             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
import numpy as np
df = pd.read_csv('../metrics.csv', index_col=0)
df.fillna(0, inplace=True)
df['Random'] = df.apply(lambda x: np.random.choice(x.dropna().values), axis=1)
#df['Random'] = df.apply(lambda x: np.random.choice(x), axis=1)
df['Oracle'] = df.max(axis=1)

#print(len(all_metric), len(df))

import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(df, showfliers=False, orient='v')
plt.xticks(rotation=90)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-845a15c566fa> in ?()
# ---> 12 import numpy as np
#      13 df = pd.read_csv('../metrics.csv', index_col=0)
#      14 df.fillna(0, inplace=True)
#      15 df['Random'] = df.apply(lambda x: np.random.choice(x.dropna().values), axis=1)
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in ?(*args, **kwargs)
#      42                         ", ".join(kwonly_args[:extra_args])),
#      43                 FutureWarning
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in ?(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2226     whis=1.5, ax=None,
#    2227     **kwargs
#    2228 ):
#    2229
# -> 2230     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2231                           orient, color, palette, saturation,
#    2232                           width, dodge, fliersize, linewidth)
#    2233
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in ?(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     402     def __init__(self, x, y, hue, data, order, hue_order,
#     403                  orient, color, palette, saturation,
#     404                  width, dodge, fliersize, linewidth):
#     405
# --> 406         self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     407         self.establish_colors(color, palette, saturation)
#     408
#     409         self.dodge = dodge
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in ?(self, x, y, hue, data, orient, order, hue_order, units)
#     152                     err = "Could not interpret input '{}'".format(var)
#     153                     raise ValueError(err)
#     154
#     155             # Figure out the plotting orientation
# --> 156             orient = infer_orient(
#     157                 x, y, orient, require_numeric=self.require_numeric
#     158             )
#     159
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_core.py in ?(x, y, orient, require_numeric)
#    1284     TypeError: When dependant variable is not numeric, with `require_numeric`
#    1285
#    1286     """
#    1287
# -> 1288     x_type = None if x is None else variable_type(x)
#    1289     y_type = None if y is None else variable_type(y)
#    1290
#    1291     nonnumeric_dv_error = "{} orientation requires numeric `{}` variable."
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_core.py in ?(vector, boolean_type)
#    1199         Name identifying the type of data in the vector.
#    1200
#    1201     """
#    1202     # Special-case all-na data, which is always "numeric"
# -> 1203     if pd.isna(vector).all():
#    1204         return "numeric"
#    1205
#    1206     # Special-case binary/boolean data, allow caller to determine
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in ?(self)
#    1525     @final
#    1526     def __nonzero__(self) -> NoReturn:
# -> 1527         raise ValueError(
#    1528             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df
# Out:
#                       AutoEncoder (AE)     CBLOF     COPOD   DeepAnT  \
# OBSEA/2020-11-03.out          0.179869  0.375253  0.274341  0.232109
# OBSEA/2020-03-16.out          0.918716  0.986496  0.917331  0.917366
# OBSEA/2020-06-04.out          0.058839  0.198123  0.082814  0.037289
# OBSEA/2020-12-03.out          0.928263  0.936971  0.919444  0.964719
# OBSEA/2020-10-03.out          0.801085  0.684449  0.462128  0.251890
# ...                                ...       ...       ...       ...
# OBSEA/2020-02-20.out          0.856573  0.980600  0.917560  0.924489
# OBSEA/2020-12-24.out          0.202628  0.245330  0.208912  0.149198
# OBSEA/2020-04-02.out          0.949561  0.976728  0.918826  0.928868
# OBSEA/2021-11-23.out          0.743542  0.981835  0.916887  0.918471
# OBSEA/2020-04-22.out          0.902924  0.983622  0.917102  0.921984
#
#                       DenoisingAutoEncoder (DAE)  EncDec-AD      HBOS  \
# OBSEA/2020-11-03.out                    0.331566   0.204318  0.343748
# OBSEA/2020-03-16.out                    0.886606   0.000000  0.530150
# OBSEA/2020-06-04.out                    0.035201   0.033576  0.124523
# OBSEA/2020-12-03.out                    0.939933   0.972615  0.909556
# OBSEA/2020-10-03.out                    0.793336   0.176748  0.559928
# ...                                          ...        ...       ...
# OBSEA/2020-02-20.out                    0.797864   0.000000  0.530941
# OBSEA/2020-12-24.out                    0.247832   0.224792  0.269665
# OBSEA/2020-04-02.out                    0.915647   0.000000  0.529800
# OBSEA/2021-11-23.out                    0.824987   0.000000  0.558570
# OBSEA/2020-04-22.out                    0.857013   0.000000  0.565791
#
#                       Hybrid KNN       LOF       PCC  RobustPCA  \
# OBSEA/2020-11-03.out    0.154503  0.375253  0.266593   0.246145
# OBSEA/2020-03-16.out    0.744666  0.999000  0.994158   0.636384
# OBSEA/2020-06-04.out    0.033979  0.198123  0.081753   0.031695
# OBSEA/2020-12-03.out    0.974520  0.936971  0.930331   0.998369
# OBSEA/2020-10-03.out    0.595054  0.684449  0.443279   0.095246
# ...                          ...       ...       ...        ...
# OBSEA/2020-02-20.out    0.745352  0.999000  0.994133   0.580729
# OBSEA/2020-12-24.out    0.202537  0.245330  0.219381   0.211030
# OBSEA/2020-04-02.out    0.744787  0.999000  0.997983   0.485937
# OBSEA/2021-11-23.out    0.744395  0.996852  0.984262   0.707630
# OBSEA/2020-04-22.out    0.744696  0.996899  0.996146   0.758127
#
#                       Random Black Forest (RR)     Torsk    Random    Oracle
# OBSEA/2020-11-03.out                  0.497478  0.556411  0.274341  0.556411
# OBSEA/2020-03-16.out                  0.743174  0.799122  0.886606  0.999000
# OBSEA/2020-06-04.out                  0.038326  0.141590  0.037289  0.198123
# OBSEA/2020-12-03.out                  0.945626  0.985211  0.939933  0.998369
# OBSEA/2020-10-03.out                  0.677349  0.283791  0.462128  0.801085
# ...                                        ...       ...       ...       ...
# OBSEA/2020-02-20.out                  0.774125  0.843532  0.856573  0.999000
# OBSEA/2020-12-24.out                  0.222021  0.664003  0.269665  0.664003
# OBSEA/2020-04-02.out                  0.699438  0.815355  0.815355  0.999000
# OBSEA/2021-11-23.out                  0.573194  0.826250  0.707630  0.996852
# OBSEA/2020-04-22.out                  0.816826  0.829291  0.816826  0.996899
#
# [540 rows x 15 columns]

# %%
fnames2keep = df.index.str.replace('OBSEA/', '').str.replace('.out', '')
fnames2keep = list(fnames2keep)
# Out:
# /tmp/ipykernel_1988921/4000371863.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   fnames2keep = df.index.str.replace('OBSEA/', '').str.replace('.out', '')

# %%
# This is to remove test data from windowed data for training (clean again)
import os
for window_data in os.listdir():
    if 'OBSEA_' not in window_data:
        continue
    
    for fname in os.listdir(window_data + '/OBSEA'):
        if '_label' not in fname:
            continue

        day = fname[:10]
        if day not in fnames2keep:
            os.remove(window_data + '/OBSEA/' + fname)
            fname = fname.replace('_label', '')
            os.remove(window_data + '/OBSEA/' + fname)

# %%
sorted(fnames2keep)
# Out:
# ['2020-01-02',
#  '2020-01-03',
#  '2020-01-05',
#  '2020-01-06',
#  '2020-01-07',
#  '2020-01-09',
#  '2020-01-14',
#  '2020-01-15',
#  '2020-01-19',
#  '2020-01-22',
#  '2020-03-22',
#  '2020-03-27',
#  '2020-03-28',
#  '2020-04-05',
#  '2020-04-08',
#  '2020-04-09',
#  '2020-04-10',
#  '2020-04-11',
#  '2020-04-14',
#  '2020-04-15',
#  '2020-04-23',
#  '2020-04-24',
#  '2020-05-01',
#  '2020-05-05',
#  '2020-05-07',
#  '2020-05-08',
#  '2020-05-09',
#  '2020-05-10',
#  '2020-05-12',
#  '2020-05-15',
#  '2020-05-16',
#  '2020-05-25',
#  '2020-05-27',
#  '2020-06-01',
#  '2020-06-02',
#  '2020-06-03',
#  '2020-06-04',
#  '2020-06-06',
#  '2020-06-07',
#  '2020-06-11',
#  '2020-06-12',
#  '2020-06-13',
#  '2020-06-14',
#  '2020-06-15',
#  '2020-06-17',
#  '2020-06-18',
#  '2020-06-19',
#  '2020-06-20',
#  '2020-06-21',
#  '2020-06-24',
#  '2020-06-26',
#  '2020-06-27',
#  '2020-06-29',
#  '2020-07-01',
#  '2020-07-02',
#  '2020-07-03',
#  '2020-07-04',
#  '2020-07-06',
#  '2020-07-07',
#  '2020-07-08',
#  '2020-07-12',
#  '2020-07-13',
#  '2020-07-15',
#  '2020-07-16',
#  '2020-07-17',
#  '2020-07-18',
#  '2020-07-19',
#  '2020-07-25',
#  '2020-07-26',
#  '2020-07-28',
#  '2020-08-01',
#  '2020-08-02',
#  '2020-08-05',
#  '2020-08-06',
#  '2020-08-07',
#  '2020-08-10',
#  '2020-08-12',
#  '2020-08-19',
#  '2020-08-20',
#  '2020-08-21',
#  '2020-08-24',
#  '2020-08-25',
#  '2020-08-26',
#  '2020-08-27',
#  '2020-08-28',
#  '2020-08-29',
#  '2020-08-31',
#  '2020-09-01',
#  '2020-09-02',
#  '2020-09-03',
#  '2020-09-04',
#  '2020-09-08',
#  '2020-09-10',
#  '2020-09-11',
#  '2020-09-13',
#  '2020-09-15',
#  '2020-09-16',
#  '2020-09-19',
#  '2020-09-25',
#  '2020-09-27',
#  '2020-09-28',
#  '2020-09-29',
#  '2020-09-30',
#  '2020-10-01',
#  '2020-10-04',
#  '2020-10-05',
#  '2020-10-06',
#  '2020-10-12',
#  '2020-10-13',
#  '2020-10-20',
#  '2020-10-22',
#  '2020-10-24',
#  '2020-10-28',
#  '2020-11-01',
#  '2020-11-03',
#  '2020-11-05',
#  '2020-11-07',
#  '2020-11-08',
#  '2020-11-10',
#  '2020-11-11',
#  '2020-11-12',
#  '2020-11-13',
#  '2020-11-14',
#  '2020-11-15',
#  '2020-11-16',
#  '2020-11-19',
#  '2020-11-21',
#  '2020-11-23',
#  '2020-11-26',
#  '2020-11-28',
#  '2020-11-29',
#  '2020-12-01',
#  '2020-12-02',
#  '2020-12-03',
#  '2020-12-04',
#  '2020-12-05',
#  '2020-12-06',
#  '2020-12-08',
#  '2020-12-09',
#  '2020-12-10',
#  '2020-12-11',
#  '2020-12-12',
#  '2020-12-13',
#  '2020-12-14',
#  '2020-12-15',
#  '2020-12-16',
#  '2020-12-17',
#  '2020-12-18',
#  '2020-12-19',
#  '2020-12-20',
#  '2020-12-21',
#  '2020-12-22',
#  '2020-12-24',
#  '2020-12-25',
#  '2020-12-26',
#  '2020-12-27',
#  '2020-12-28',
#  '2021-01-02',
#  '2021-01-03',
#  '2021-01-05',
#  '2021-01-06',
#  '2021-01-08',
#  '2021-01-09',
#  '2021-01-10',
#  '2021-01-11',
#  '2021-01-15',
#  '2021-01-16',
#  '2021-01-18',
#  '2021-01-19',
#  '2021-01-20',
#  '2021-01-21',
#  '2021-01-22',
#  '2021-01-23',
#  '2021-01-24',
#  '2021-01-25',
#  '2021-01-26',
#  '2021-01-27',
#  '2021-01-28',
#  '2021-01-29',
#  '2021-01-30',
#  '2021-01-31',
#  '2021-02-01',
#  '2021-02-02',
#  '2021-02-03',
#  '2021-02-05',
#  '2021-02-10',
#  '2021-02-11',
#  '2021-02-12',
#  '2021-03-16',
#  '2021-03-19',
#  '2021-07-22',
#  '2021-07-26',
#  '2021-07-29',
#  '2021-07-31',
#  '2021-08-02',
#  '2021-08-05',
#  '2021-08-06',
#  '2021-08-08',
#  '2021-08-09',
#  '2021-08-10',
#  '2021-08-12',
#  '2021-08-15',
#  '2021-08-23',
#  '2021-08-24',
#  '2021-08-28',
#  '2021-08-29',
#  '2021-08-30',
#  '2021-09-02',
#  '2021-09-04',
#  '2021-09-05',
#  '2021-09-06',
#  '2021-09-07',
#  '2021-09-08',
#  '2021-09-13',
#  '2021-09-15',
#  '2021-09-16',
#  '2021-09-19',
#  '2021-09-20',
#  '2021-09-21',
#  '2021-09-23',
#  '2021-09-25',
#  '2021-09-28',
#  '2021-09-29',
#  '2021-09-30',
#  '2021-10-01',
#  '2021-10-02',
#  '2021-10-03',
#  '2021-10-04',
#  '2021-10-05',
#  '2021-10-06',
#  '2021-10-07',
#  '2021-10-09',
#  '2021-10-10',
#  '2021-10-15',
#  '2021-10-22',
#  '2021-10-29',
#  '2021-11-01',
#  '2021-11-06',
#  '2021-11-07',
#  '2021-11-10',
#  '2021-11-15',
#  '2021-11-17',
#  '2021-11-19',
#  '2021-11-20',
#  '2021-11-23',
#  '2021-11-24',
#  '2021-11-25',
#  '2021-11-26',
#  '2021-11-27',
#  '2021-11-29',
#  '2021-11-30',
#  '2021-12-02',
#  '2021-12-03',
#  '2021-12-04',
#  '2021-12-05',
#  '2021-12-06',
#  '2021-12-11',
#  '2021-12-13',
#  '2021-12-14',
#  '2021-12-15',
#  '2021-12-17',
#  '2021-12-19',
#  '2021-12-20',
#  '2021-12-21',
#  '2021-12-22',
#  '2021-12-23',
#  '2021-12-27',
#  '2021-12-30']

# %%
# prepare train_val_split
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

# read metrics generated by create_window_data
df = pd.read_csv('../metrics.csv', index_col=0)
df = df[(df.index.str.contains('2020')) | (df.index.str.contains('2021'))]# | (df.index.str.contains('2021'))] 

#df.drop(['CBLOF', 'LOF', 'PCC'], axis=1, inplace=True)
df['Random'] = df.apply(lambda x: np.random.choice(x), axis=1)
df['Oracle'] = df.max(axis=1)


# Melt the DataFrame to long format
df_long = df.melt(var_name='Method', value_name='Score')

# Create the boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x='Method', y='Score', data=df_long, showfliers=False)
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
df.describe().T
# Out:
#                             count      mean       std       min       25%  \
# AutoEncoder (AE)            271.0  0.664318  0.340522  0.004950  0.359669
# DenoisingAutoEncoder (DAE)  271.0  0.665448  0.332798  0.013364  0.362443
# DeepAnT                     271.0  0.640835  0.338718  0.004516  0.304880
# HBOS                        271.0  0.548318  0.211975  0.010492  0.422220
# COPOD                       271.0  0.659969  0.324681  0.004999  0.391877
# RobustPCA                   271.0  0.535389  0.243412  0.003725  0.360898
# Random                      271.0  0.613913  0.308660  0.017333  0.374893
# Oracle                      271.0  0.795150  0.246624  0.050092  0.666048
#
#                                  50%       75%       max
# AutoEncoder (AE)            0.820481  0.950980  0.999242
# DenoisingAutoEncoder (DAE)  0.844948  0.942747  0.996717
# DeepAnT                     0.815105  0.915751  0.999738
# HBOS                        0.549372  0.670553  0.998716
# COPOD                       0.817543  0.929223  0.998690
# RobustPCA                   0.573925  0.717727  0.999860
# Random                      0.692544  0.899694  0.998690
# Oracle                      0.930388  0.971062  0.999860

# %%
str(0.3)
# Out:
# '0.3'
