# %% [markdown]
# # notebook to prepare data

# %%
import os
import shutil
import pandas as pd
import numpy as np

# %%
root_path = '/mnt/c/Arbeid/Github_Repo/MSAD_work/'

# %%
def concat_results(directory):
    dfs = list()
    
    # Iterate through execution dates
    for exec_folder in os.listdir(directory):
        for file in os.listdir(os.path.join(directory, exec_folder)):
            if file == 'results.csv':
                filepath = os.path.join(directory, exec_folder, file)
                df = pd.read_csv(filepath)
                df['result_path'] = filepath
                dfs.append(df)
    
    return pd.concat([df.reset_index(drop=True) for df in dfs], ignore_index=True)

directory = '/mnt/c/Arbeid/Github_Repo/TimeEval_work/results'
all_results = concat_results(directory)

# %%
obsea_results = all_results[(all_results['collection'] == 'OBSEA') | (all_results['collection'] == 'OBSEA_2')]
obsea_results = obsea_results[(obsea_results['BestF1Score'].notna()) & (obsea_results['FalseNegativeRate'].notna())]
obsea_results['collection'][obsea_results['collection'] == 'OBSEA_2'] = 'OBSEA'
obsea_results['Recommendation_ACC'] =  obsea_results.apply(lambda row: max(row['BestF1Score'] - row['FalseNegativeRate'], 0), axis=1)
obsea_results
# Out:
#                        algorithm collection                  dataset  \
# 1                            PCC      OBSEA  2020-01-01_unsupervised
# 3                            PCC      OBSEA  2020-01-02_unsupervised
# 5                            PCC      OBSEA  2020-01-03_unsupervised
# 7                            PCC      OBSEA  2020-01-04_unsupervised
# 9                            PCC      OBSEA  2020-01-05_unsupervised
# ...                          ...        ...                      ...
# 124097  Random Black Forest (RR)      OBSEA               2020-10-09
# 124103                   DeepAnT      OBSEA               2020-09-27
# 124107                   DeepAnT      OBSEA               2020-09-29
# 124123                   DeepAnT      OBSEA               2020-10-07
# 124125                   DeepAnT      OBSEA               2020-10-08
#
#        algo_training_type algo_input_dimensionality dataset_training_type  \
# 1            unsupervised              multivariate          multivariate
# 3            unsupervised              multivariate          multivariate
# 5            unsupervised              multivariate          multivariate
# 7            unsupervised              multivariate          multivariate
# 9            unsupervised              multivariate          multivariate
# ...                   ...                       ...                   ...
# 124097    semi-supervised              multivariate          multivariate
# 124103    semi-supervised              multivariate          multivariate
# 124107    semi-supervised              multivariate          multivariate
# 124123    semi-supervised              multivariate          multivariate
# 124125    semi-supervised              multivariate          multivariate
#
#        dataset_input_dimensionality     status  \
# 1                      unsupervised  Status.OK
# 3                      unsupervised  Status.OK
# 5                      unsupervised  Status.OK
# 7                      unsupervised  Status.OK
# 9                      unsupervised  Status.OK
# ...                             ...        ...
# 124097              semi-supervised  Status.OK
# 124103              semi-supervised  Status.OK
# 124107              semi-supervised  Status.OK
# 124123              semi-supervised  Status.OK
# 124125              semi-supervised  Status.OK
#
#                          hyper_params_id  repetition  ...  \
# 1       6f4f0a7ce802ffdcb5a6590625043544           1  ...
# 3       6f4f0a7ce802ffdcb5a6590625043544           1  ...
# 5       6f4f0a7ce802ffdcb5a6590625043544           1  ...
# 7       6f4f0a7ce802ffdcb5a6590625043544           1  ...
# 9       6f4f0a7ce802ffdcb5a6590625043544           1  ...
# ...                                  ...         ...  ...
# 124097  d82d967f453c8877b8c563e6747347c0           1  ...
# 124103  f1d3356f9300f17a84a6becaa8cf8758           1  ...
# 124107  f1d3356f9300f17a84a6becaa8cf8758           1  ...
# 124123  f1d3356f9300f17a84a6becaa8cf8758           1  ...
# 124125  f1d3356f9300f17a84a6becaa8cf8758           1  ...
#
#        execute_postprocess_time   ROC_AUC  RANGE_PR_AUC  BestF1Score  \
# 1                           NaN       NaN           NaN     0.000000
# 3                           NaN  0.741747      0.072803     0.065241
# 5                           NaN  0.892717      0.235710     0.321365
# 7                           NaN  0.885682      0.289441     0.734900
# 9                           NaN  0.378695      0.107028     0.073372
# ...                         ...       ...           ...          ...
# 124097                      NaN  0.573922      0.200308     0.096942
# 124103                 0.046996       NaN           NaN     0.000000
# 124107                 0.340805  0.543787      0.276727     0.277851
# 124123                 0.228107  0.697546      0.240006     0.323591
# 124125                 0.376654  0.459072      0.069953     0.129429
#
#         FalseNegativeRate                                        result_path  \
# 1                0.000000  /mnt/c/Arbeid/Github_Repo/TimeEval_work/result...
# 3                0.043956  /mnt/c/Arbeid/Github_Repo/TimeEval_work/result...
# 5                0.000000  /mnt/c/Arbeid/Github_Repo/TimeEval_work/result...
# 7                0.128067  /mnt/c/Arbeid/Github_Repo/TimeEval_work/result...
# 9                0.000000  /mnt/c/Arbeid/Github_Repo/TimeEval_work/result...
# ...                   ...                                                ...
# 124097           0.769716  /mnt/c/Arbeid/Github_Repo/TimeEval_work/result...
# 124103           0.000000  /mnt/c/Arbeid/Github_Repo/TimeEval_work/result...
# 124107           0.195271  /mnt/c/Arbeid/Github_Repo/TimeEval_work/result...
# 124123           0.750865  /mnt/c/Arbeid/Github_Repo/TimeEval_work/result...
# 124125           0.251880  /mnt/c/Arbeid/Github_Repo/TimeEval_work/result...
#
#         train_main_time  train_preprocess_time train_postprocess_time  \
# 1                   NaN                    NaN                    NaN
# 3                   NaN                    NaN                    NaN
# 5                   NaN                    NaN                    NaN
# 7                   NaN                    NaN                    NaN
# 9                   NaN                    NaN                    NaN
# ...                 ...                    ...                    ...
# 124097      2714.143344                    NaN                    NaN
# 124103     10811.539529                    NaN                    NaN
# 124107     10811.291509                    NaN                    NaN
# 124123     10811.478486                    NaN                    NaN
# 124125     10811.621041                    NaN                    NaN
#
#         Recommendation_ACC
# 1                 0.000000
# 3                 0.021285
# 5                 0.321365
# 7                 0.606833
# 9                 0.073372
# ...                    ...
# 124097            0.000000
# 124103            0.000000
# 124107            0.082579
# 124123            0.000000
# 124125            0.000000
#
# [24601 rows x 23 columns]

# %%
#obsea_results = obsea_results[:500]
#obsea_results

# %%
obsea_results['algorithm'].unique()
# Out:
# array(['PCC', 'HBOS', 'Torsk', 'AutoEncoder (AE)',
#        'DenoisingAutoEncoder (DAE)', 'EncDec-AD', 'DeepAnT', 'Hybrid KNN',
#        'CBLOF', 'COPOD', 'Random Black Forest (RR)', 'RobustPCA', 'LOF'],
#       dtype=object)

# %%
# copy data
dest_path = root_path + 'data/OBSEA/data'
src_path = '/mnt/c/Arbeid/Github_Repo/TimeEval_work/work_data/processed/multivariate/OBSEA'
for data_file in os.listdir(src_path):
    if 'test' in data_file:
        df = pd.read_csv(src_path + '/' + data_file)
        df.drop(df.columns[0], axis=1, inplace=True)
        df.to_csv(dest_path + '/' + data_file.split('.')[0] + '.out', index=False, header=False)

# %%
# copy scores
dest_path = root_path + 'data/OBSEA/scores'
for row_idx in range(len(obsea_results)):
    try:
        result_path = '/'.join(obsea_results.iloc[row_idx, obsea_results.columns.get_loc('result_path')].split('/')[:-1])
        algorithm = obsea_results.iloc[row_idx, obsea_results.columns.get_loc('algorithm')]
        hyper_params_id = obsea_results.iloc[row_idx, obsea_results.columns.get_loc('hyper_params_id')]
        collection = obsea_results.iloc[row_idx, obsea_results.columns.get_loc('collection')]
        dataset = obsea_results.iloc[row_idx, obsea_results.columns.get_loc('dataset')]
        repetition = str(obsea_results.iloc[row_idx, obsea_results.columns.get_loc('repetition')])
        scores_file_name = 'docker-algorithm-scores.csv'
        src_path = result_path + '/' + algorithm + '/' + hyper_params_id + '/' + collection + '/' + dataset + '/' + repetition + '/' + scores_file_name
        scores_dir_alg = dest_path + '/' + algorithm
        os.makedirs(scores_dir_alg, exist_ok=True)
        dest_score_path = scores_dir_alg + '/' + dataset.split('_')[0] + '.out'
        shutil.copy(src_path, dest_score_path)
    except:
        pass

# %%
# copy metrics
path_to_metrics = root_path + 'data/OBSEA/metrics'
metrics = ['ROC_AUC', 'RANGE_PR_AUC', 'BestF1Score', 'FalseNegativeRate', 'Recommendation_ACC']
exec_algorithms = obsea_results['algorithm'].unique()
for exec_algorithm in exec_algorithms:
    for metric in metrics:
        df = obsea_results[(obsea_results['algorithm'] == exec_algorithm)]
        df = df[['dataset', metric]]
        df['dataset'] = df['dataset'].str.strip().str.replace('_unsupervised', '.out')
        df['dataset'] = df['dataset'].apply(lambda x: x + '.out' if not x.endswith('.out') else x)
        df['dataset'] = df['dataset'].apply(lambda x: 'OBSEA/' + x)
        df.set_index('dataset', inplace=True)
        df.index.name = ''
        df = df.groupby(level=0).min()
        df.rename(columns={metric: exec_algorithm}, inplace=True)
        df.dropna(inplace=True)
        metrics_dir_alg = path_to_metrics + '/' + exec_algorithm
        os.makedirs(metrics_dir_alg, exist_ok=True)
        #print(df)
        df.to_csv(metrics_dir_alg + '/' + metric + '.csv')
